# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
import pandas
import pytry
import numpy as np
import nengo
# Out:
# c:\users\terry\py3\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
data = pytry.read('exp10')
data2 = []
for d in data:
    d2 = dict(d)
    d2['rmse'] = d['rmse_in_range'][0]*36/25
    d2['axis'] = 'x'
    data2.append(d2)

    d2 = dict(d)
    d2['rmse'] = d['rmse_in_range'][1]*36/25
    d2['axis'] = 'y'
    data2.append(d2)
    
df = pandas.DataFrame(data2)

# %%
seaborn.barplot('n_epochs', 'rmse', hue='axis', data=df, estimator=np.mean)
plt.xlabel('number of epochs of training')
plt.ylabel('rmse (mm)')
# Out:
# Text(0, 0.5, 'rmse (mm)')

# %%
d.keys()
# Out:
# dict_keys(['seed', 'n_data', 'dataset_dir', 'dt', 'dt_test', 'decay_time', 'test_set', 'augment', 'minibatch_size', 'learning_rate', 'n_epochs', 'saturation', 'separate_channels', 'n_features_1', 'n_features_2', 'split_spatial', 'spatial_stride', 'spatial_size', 'n_parallel', 'merge', 'normalize', 'save_params', 'load_params_from', 'use_nengo', 'input_data', 'rmse_test', 'rmse_in_range', 'max_n_neurons', 'test_targets_raw', 'target_peak', 'data_peak', 'test_loss'])

# %%
data = list(pytry.read('exp10'))
d = data[2+4*0]

print(d['n_features_1'])
#plt.plot(d['test_targets_raw']-3, ls='--')
plt.plot(d['data_peak']*d['merge'])
plt.plot(d['target_peak']*d['merge'], ls='--')
plt.legend(['x', 'y', 'x (actual)', 'y (actual)'])
plt.xlabel('time (ms)')
plt.ylabel('pixels')
# Out:
# 10
# Text(0, 0.5, 'pixels')

# %%
data[-1]['seed']
# Out:
# 18

# %%
len(data)
# Out:
# 18
